# %%
import pandas as pd

# %%
df = pd.read_csv("Data.csv")

# %%
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.isnull().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

from nltk.corpus import stopwords

# %%
for i in range(0,5572):
    df.iloc[i,1] = word_tokenize(df.iloc[i,1])
    lst = df.iloc[i,1]
    for j in range(0,len(lst)):
        if lst[j] not in stopwords.words("english"):
            new_word = lemmatizer.lemmatize(lst[j])
            lst[j] = new_word
        else:
            lst[j] = " "

# %%
for i in range(0,5572):
    df.iloc[i,1] = " ".join(df.iloc[i,1])
    df.iloc[i,1] = df.iloc[i,1].lower()

# %%
df.head()
# Out:
#   Category                                            Message
# 0      ham  go   jurong point , crazy .. available     bug...
# 1      ham                    ok lar ... joking wif u oni ...
# 2     spam  free entry   2   wkly comp   win fa cup final ...
# 3      ham    u dun say   early hor ... u c already   say ...
# 4      ham  nah i   n't think   go   usf ,   life around  ...

# %%
df['Category'] = df['Category'].map({
       'spam': 1,
        'ham': 0,
   })

# %%
df.head()
# Out:
#    Category                                            Message
# 0         0  go   jurong point , crazy .. available     bug...
# 1         0                    ok lar ... joking wif u oni ...
# 2         1  free entry   2   wkly comp   win fa cup final ...
# 3         0    u dun say   early hor ... u c already   say ...
# 4         0  nah i   n't think   go   usf ,   life around  ...

# %%
X = df["Message"]
Y = df["Category"]

# %%
df.head()
# Out:
#    Category                                            Message
# 0         0  go   jurong point , crazy .. available     bug...
# 1         0                    ok lar ... joking wif u oni ...
# 2         1  free entry   2   wkly comp   win fa cup final ...
# 3         0    u dun say   early hor ... u c already   say ...
# 4         0  nah i   n't think   go   usf ,   life around  ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 20, random_state = 42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train).toarray()
X_test_vec = vectorizer.transform(X_test).toarray()

# %%
df.head()
# Out:
#    Category                                            Message
# 0         0  go   jurong point , crazy .. available     bug...
# 1         0                    ok lar ... joking wif u oni ...
# 2         1  free entry   2   wkly comp   win fa cup final ...
# 3         0    u dun say   early hor ... u c already   say ...
# 4         0  nah i   n't think   go   usf ,   life around  ...

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model = MultinomialNB()

# %%
model.fit(X_train_vec,Y_train)
# Out:
# MultinomialNB()

# %%
model.score(X_train_vec, Y_train)
# Out:
# 0.9830691642651297

# %%
model.score(X_test_vec, Y_test)
# Out:
# 1.0

# %%
import pickle
pickle_out = open("model.pkl", "wb")
pickle.dump(model, pickle_out)
pickle_out.close()

with open("vectorizer.pkl", "wb") as f:
    pickle.dump(cv, f)
